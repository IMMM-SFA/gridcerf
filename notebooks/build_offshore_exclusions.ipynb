# %% [markdown]
# # Build offshore exclusion areas for GRIDCERF

# %% [markdown]
# The following code was used to build the offshore exclusion layers for GRIDCERF. GRIDCERF does not provide the source data directly due to some license restrictions related for direct redistribution of the unaltered source data.  However, the following details the provenance associated with each source dataset and how they were processed.

# %% [markdown]
# ## 1. Setup environment

# %% [markdown]
# ### 1.1 Download GRIDCERF
#
# Download the GRIDCERF package if you have not yet done so from here:  https://doi.org/10.5281/zenodo.6601789.  Please extract GRIDCERF inside the `data` directory of this repository as the paths in this notebook are set to that expectation.

# %% [markdown]
# ### 1.2 Data description

# %% [markdown]
# - **Title**: National Marine Sanctuary Program Digital Boundary Files
# - **Description from Source**: The Office of National Marine Sanctuaries manages a system of sanctuaries and other managed areas around the country. The legal boundaries of these sanctuaries are defined within the Code of Federal Regulations, at 15 C.F.R. Part 922 and the subparts for each national marine sanctuary. The GIS compatible digital boundary files for each national marine sanctuary are representations of those legal boundaries and are based on the best available data. These files are available for public use at locations defined in this metadata record.
# - **Boundaries Included**: Channel Islands, Cordell Bank, Florida Keys, Flower Garden Banks, Gray's Reef, Greater Farallones, Mallows Bay-Potomac River, Monitor, Monterey Bay, Olympic Coast, Stellwagen Bank, Thunder Bay, Wisconsin Shipwreck.
#
# - **Source URL**:  https://sanctuaries.noaa.gov/library/imast_gis.html
# - **Date Accessed**:  9/22/23
# - **Citation**
# > NOAA / National Marine Sanctuaries Program. National Marine Sanctuary Program Digital Boundary Files. NOAA/National Marine Sanctuaries Program, Silver Spring, Maryland. https://sanctuaries.noaa.gov/library/imast_gis.html.
# - **Application**: The gridcerf exclusion layer excludes these areas outright with no additional buffer.
#
# _________
#
# - **Title**:  Danger Zones and Restricted Areas
# - **Description from Source**: These data represent the location of Danger Zones and Restricted Areas within coastal and marine waters, as outlined by the Code of Federal Regulations (CFR) and the Raster Navigational Charts (RNC). The CFR defines a Danger Zone as, "A defined water area (or areas) used for target practice, bombing, rocket firing or other especially hazardous operations, normally for the armed forces. The danger zones may be closed to the public on a full-time or intermittent basis, as stated in the regulations." The CFR defines a Restricted Area as, "A defined water area for the purpose of prohibiting or limiting public access to the area. Restricted areas generally provide security for Government property and/or protection to the public from the risks of damage or injury arising from the Government's use of that area." Other features in this dataset include: Danger Area, Missile Testing Area, Naval Operations Area, Prohibited Area, Restricted Airspace, Test Area, and Torpedo Testing Area. Authoritative information relating to these data may be found in Title 33, Chapter II of the CFR (Part 334).
#
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::danger-zones-and-restricted-areas/about
# - **Date Accessed**:  9/22/23
# - **Citation**
# > Office for Coastal Management, 2023. Danger Zones and Restricted Areas. NOAA National Centers for Environmental Information, https://www.fisheries.noaa.gov/inport/item/48876.
# - **Application**: The gridcerf exclusion layer excludes these areas outright with no additional buffer.
#
# _________
#
#
# - **Title**:  Munitions and Explosives of Concern
# - **Description from Source**: Munitions and explosives of concern (MEC) have been deposited on the seabed of the United States Outer Continental Shelf since World War I. The bulk of these munitions have originated from the U.S. Armed Forces while conducting military training exercises, war-time placement, and disposal and dumping activities. Since 1972, ocean disposal of munitions and other pollutants has been banned by the Marine Protection, Research, and Sanctuaries Act. Federal and state efforts to mitigate, map, monitor, and sometimes remove these munitions are ongoing. The term MEC defines a collection of munitions including a) unexploded ordnance, b) discarded military munitions, and c) munition constituents that are present in high enough concentrations to pose an explosive hazard.
#
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::munitions-and-explosives-of-concern/about
# - **Date Accessed**:  9/22/23
# - **Citation**
# > Office for Coastal Management, 2023: Munitions and Explosives of Concern  NOAA National Centers for Environmental Information, https://www.fisheries.noaa.gov/inport/item/69013.
# - **Application**: The gridcerf exclusion layer excludes these areas outright with no additional buffer.
#
# _________
#
#
# - **Title**:  Wrecks and Obstructions
# - **Description from Source**: Shipwrecks and obstructions in the ocean have long been a hazard to navigation and construction, and points of interest to archaeologists, recreational divers, fishermen, educators, and explorers. Locating hazardous wrecks and obstructions is part of the ongoing NOAA charting process. The exact position of many wrecks is difficult to determine because of changes in the environment, varied survey methods, and human error. Some wrecks are intentionally placed in the ocean to serve as artificial reefs or for disposal. Others pose a health and environmental threat from their cargo. Ownership and control over wrecks and obstructions is governed by a collection of state and federal regulations, the Abandoned Shipwreck Act, National Historic Preservation Act, and National Marine Sanctuaries Act.
#
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::wrecks-and-obstructions/about
# - **Date Accessed**:  9/25/23
# - **Citation**
# > Office for Coastal Management, 2023: Wrecks and Obstructions. NOAA National Centers for Environmental Information, https://www.fisheries.noaa.gov/inport/item/70439.
# - **Application**: The gridcerf exclusion layer excludes these areas outright with no additional buffer.
#
# _________
#
#
# - **Title**:  Outer Continental Shelf Areas Withdrawn from Leasing
# - **Description from Source**: These data represent areas that are permanently or temporarily withdrawn from oil, gas, renewable, critical mineral, or sand leasing or some combination of these by various authorities, including the Gulf of Mexico Security Act of 2006, presidential withdrawals under Sec. 12 of the Outer Continental Shelf Lands Act, 43 U.S.C. Sec. 1341, or the National Marine Sanctuaries Act, 16 U.S.C. Sec. 1431-1434, 33 U.S.C. 1401 et seq. Additionally, some marine national monuments within the area under BOEM's leasing authority include language that restricts certain types of leases.
#
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::outer-continental-shelf-areas-withdrawn-from-leasing/about
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  Bureau of Ocean Energy Management - Office of Strategic Resouces, 2021: BOEM Outer Continental Shelf Areas Withdrawn from Leasing. Departement of Interior - Bureau of Ocean Energy Management, https://www.boem.gov/oil-gas-energy/leasing/boemocsareas-withdrawn-leasing-2021.zip
#
# - **Application**: For the GRIDCERF Layer, only excluded areas that are applicable to renewable energy development ('ORSM', 'ORM') and those that are permanently excluded are added to the exclusion area.
# _________
#
#
# - **Title**:  Habitat Areas of Particular Concern
# - **Description from Source**: The purpose of HAPCs is to focus conservation, management, and research efforts on subsets of EFH that are vulnerable to degradation or are especially important ecologically for federally managed fish. The HAPC designation alone does not confer additional protection or restrictions to an area, but helps to focus EFH conservation, management, and research priorities. HAPC designation is a valuable way to acknowledge areas where we have detailed information on ecological function and habitat vulnerability, indicating a greater need for conservation and management. In some instances the Councils and NMFS may develop fishery management measures to conserve the habitat within the HAPC.
# -
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::habitat-areas-of-particular-concern/about
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  NOAA, 2023: Habitat Areas of Particular Concern. National Oceanic Atmospheric Administration, https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::habitat-areas-of-particular-concern/about
#
# - **Application**: The gridcerf exclusion layer excludes these areas outright with no additional buffer.
# _________
# - **Title**:  Shipping Fairways, Lanes, and Zones for US waters
# - **Description from Source**: The automatic identification system (AIS) is a navigation safety device that transmits and monitors the location and characteristics of many vessels in U.S. and international waters in real time. In the U.S., the Coast Guard and industry collect AIS data, which can also be used for a variety of coastal planning purposes. NOAA and BOEM have worked jointly to add value and make available some of the most important historical records from the U.S. Coast Guard's national network of AIS receivers. This data set represents annual vessel transit counts summarized at a 100-meter by 100-meter geographic area. A single transit is counted each time a vessel track passes through, starts, or stops within a 100-meter grid cell.
# -
# - **Source URL**:  https://www.fisheries.noaa.gov/inport/item/39986
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  Office of Coast Survey, 2023: Shipping Fairways, Lanes, and Zones for US waters. NOAA National Centers for Environmental Information, https://www.fisheries.noaa.gov/inport/item/39986.
#
# - **Application**: The gridcerf exclusion layer excludes Shipping Fairways Lanes and Zones, Traffic Separation Schemes, Traffic Separateion Schemes/Traffic Lanes, and Recommended Routes + a 3 km buffer
# _________
#
# - **Title**:  2022 TIGER/Line® Shapefiles: Coastline
# - **Description from Source**: The 2022 TIGER/Line Shapefiles contain current geographic extent and boundaries of both legal and statistical entities (which have no governmental standing) for the United States, the District of Columbia, Puerto Rico, and the Island areas. This vintage includes boundaries of governmental units that match the data from the surveys that use 2022 geography (e.g., the 2022 American Community Survey).
# - **Source URL**:  https://www2.census.gov/geo/tiger/TIGER2022/COASTLINE/tl_2022_us_coastline.zip
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  US Census Bureau, 2022. TIGER/Line Shapefiles: Coastline. Geography Division, U.S. Census Bureau, https://www2.census.gov/geo/tiger/TIGER2022/COASTLINE/tl_2022_us_coastline.zip
#
# - **Application**: Offshore energy development falls under the purview of the US Bureau of Ocean Energy Management and is built in federal waters. Federal waters begin approximately 3 miles offshore. This notebook develops the state water exlusion area for offshore energy development. Submerged state lands that are not under the purview of the BOEM (e.g., Great Lakes) are not included.
# .
# _________
#
# - **Title**:  Submarine Cable Areas
# - **Description from Source**: These data show the general location of commercial and research submarine cables within U.S. waters. The majority of these cables are for telecommunications, and the remaining are for power transmission. The geographic footprint for each cable may vary and is dependent on the original source data. In the near shore, cables are routinely buried below the seabed. Offshore, they are placed directly on the seabed. A submarine cable area may contain one or more physical cables, and 30 CFR 585.301 defines a minimum 100-foot-wide right of way grant on each side of a cable.
# - **Source URL**:  https://marinecadastre-noaa.hub.arcgis.com/datasets/noaa::submarine-cable-areas/about
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  Office for Coastal Management, 2023: U.S. State Submerged Lands from 2010-06-15 to 2010-08-15. NOAA National Centers for Environmental Information, https://www.fisheries.noaa.gov/inport/item/48928.
#
# - **Application**: The gridcerf exclusion layer excludes these areas + 1km buffer from the rasterization process.
# ________
#
# - **Title**:  2022 TIGER/Line® Shapefiles: States (and equivalent)
# - **Description from Source**: The 2022 TIGER/Line Shapefiles contain current geographic extent and boundaries of both legal and statistical entities (which have no governmental standing) for the United States, the District of Columbia, Puerto Rico, and the Island areas. This vintage includes boundaries of governmental units that match the data from the surveys that use 2022 geography (e.g., the 2022 American Community Survey).
# - **Source URL**:  https://www2.census.gov/geo/tiger/TIGER2022/STATE/tl_2022_us_state.zip
# - **Date Accessed**:  9/25/23
# - **Citation**
# >  US Census Bureau, 2022. TIGER/Line Shapefiles: States (and equivalent). Geography Division, U.S. Census Bureau, https://www2.census.gov/geo/tiger/TIGER2022/STATE/tl_2022_us_state.zip
#
# - **Application**: The gridcerf exclusion layer excludes all land areas from offshore energy siting.
# __________

# %% [markdown]
# ### 1.3 Import modules

# %%
import os

import pandas as pd
import geopandas as gpd
import numpy as np
import rasterio
from rasterio import features

# %% [markdown]
# ## 2. Configuration

# %%
# get the parent directory path to where this notebook is currently stored
root_dir = os.path.dirname(os.getcwd())

# data directory in repository
data_dir = os.path.join(root_dir, "data")

# GRIDCERF data directory from downloaded archive
gridcerf_dir = os.path.join(data_dir, "gridcerf")

# GRIDCERF reference data directory
reference_dir = os.path.join(gridcerf_dir, "reference")

# GRIDCERF technology_specific data directory
technology_specific_dir = os.path.join(gridcerf_dir, "technology_specific")

# GRIDCERF compiled final suitability data directory
compiled_dir = os.path.join(gridcerf_dir, "compiled")

# template siting mask raster
template_raster = os.path.join(reference_dir, "gridcerf_sitingmask.tif")

# template conus mask raster
conus_mask = os.path.join(reference_dir, "gridcerf_landmask.tif")

# Siting boundary shapefile
conus_shpfile = os.path.join(reference_dir, "gridcerf_siting_boundary.shp")

# conus land shpfile
conus_land_shpfile = os.path.join(reference_dir,  "gridcerf_conus_boundary.shp")


# source files
# --------------------------

# GRIDCERF source data directories
tech_specific_dir = os.path.join(gridcerf_dir, "source", "technology_specific")
marine_sanctuaries_source_dir =  os.path.join(tech_specific_dir, "marine_sanctuaries")
danger_zones_source_dir = os.path.join(tech_specific_dir, "offshore_danger_zones")
munitions_source_dir = os.path.join(tech_specific_dir,  "offshore_munitions")
lease_withdrawal_dir = os.path.join(tech_specific_dir,  "offshore_areas_withdrawn_from_leasing")
hapc_dir = os.path.join(tech_specific_dir,  "offshore_habitats_of_particular_concern")
shipping_lane_dir = os.path.join(tech_specific_dir,  "offshore_shipping_lanes")
submarine_cable_dir = os.path.join(tech_specific_dir,  "offshore_submarine_cables")
wrecks_dir = os.path.join(tech_specific_dir,  "offshore_wrecks_obstructions")
state_waters_dir = os.path.join(tech_specific_dir,  "offshore_state_waters")

# shapefile location for marine sanctuaries
wisconsin_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 
                                    '2021-wisconsin-shipwreck-coast-national-marine-sanctuary_py', 'WSCNMS_py.shp')
cordell_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'cbnms_py2', 'CBNMS_py.shp')
channel_islands_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'cinms_py2', 'cinms_py.shp')
flower_garden_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'fgbnms_py', 'FGBNMS_py.shp')
florida_keys_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'fknms_py2', 'fknms_py.shp')
greater_farallones_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'gfnms_py2', 'GFNMS_py.shp')
grays_reef_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'grnms_py2', 'grnms_py.shp')
monterey_bay_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'mbnms_py2', 'mbnms_py.shp')
monitor_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'mnms_py2', 'mnms_py.shp')
mallows_bay_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'MBPR_py', 'MBPR_py.shp')
olympic_coast_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'ocnms_py2', 'ocnms_py.shp')
stellwagen_bank_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'sbnms_py2', 'sbnms_py.shp')
thunder_bay_ms_shpfile = os.path.join(marine_sanctuaries_source_dir, 'tbnms_py2', 'tbnms_py.shp')

# danger zones and restricted areas
offshore_dz_shpfile = os.path.join(danger_zones_source_dir, 'Danger_Zones_and_Restricted_Areas', 
                                   'Danger_Zones_and_Restricted_Areas.shp')

# munitions and explosives of concern
offshore_munitions_shpfile = os.path.join(munitions_source_dir, 'Munitions_and_Explosives_of_Concern', 
                                   'Munitions_and_Explosives_of_Concern.shp')

# offshore wrecks and obstructions
offshore_wrecks_shpfile = os.path.join(wrecks_dir, 'Wrecks_and_Obstructions', 'Wrecks_and_Obstructions.shp')

# offshore areas withdrawn from leasing
withdrawn_leasing_shpfile= os.path.join(lease_withdrawal_dir, "Outer_Continental_Shelf_Areas_Withdrawn_from_Leasing", 
                                        'BOEM_OCS_Areas_Withdrawn_from_Leasing.shp')

# offshore habitats of particular concern
offshore_hapc_shpfile = os.path.join(hapc_dir, 'Habitat_Areas_of_Particular_Concern', 'Habitat_Areas_of_Particular_Concern.shp')

# high density shipping lanes
shipping_land_shpfile = os.path.join(shipping_lane_dir, 'shippinglanes', 'shippinglanes.shp')

# state waters
state_waters_shpfile = os.path.join(state_waters_dir, 'tl_2021_us_coastline', "tl_2021_us_coastline.shp")

# submarine cable areas
submarine_cable_shpfile  = os.path.join(submarine_cable_dir,'Submarine_Cable_Areas', 'Submarine_Cable_Areas.shp')

# -----------------------------

# output rasters
output_marine_sanctuaries_file = os.path.join(technology_specific_dir, "gridcerf_noaa_marine_sanctuaries.tif")
output_danger_zone_file = os.path.join(technology_specific_dir, "gridcerf_noaa_offshore_danger_zones.tif")
output_munitions_file = os.path.join(technology_specific_dir, "gridcerf_noaa_offshore_munitions_zones.tif")
output_wrecks_file =  os.path.join(technology_specific_dir, "gridcerf_noaa_offshore_wrecks_obstructions.tif")
output_lease_file =  os.path.join(technology_specific_dir, "gridcerf_offshore_areas_withdrawn_from_leasing.tif")
output_hapc_file =  os.path.join(technology_specific_dir, "gridcerf_noaa_habitats_of_particular_concern.tif")
output_shipping_file = os.path.join(technology_specific_dir, "gridcerf_noaa_shipping_lanes_regulations.tif")
output_state_waters_file =  os.path.join(technology_specific_dir, "gridcerf_uscb_state_oceanic_waters.tif")
output_cable_file =  os.path.join(technology_specific_dir, "gridcerf_noaa_submarine_cable_areas.tif")
output_conus_land_file =  os.path.join(technology_specific_dir, "gridcerf_conus_land_areas.tif")


# factor for converting a mile to meter
mi_to_meter = 1609.34

# crs for converting projections
crs = 'ESRI:102003'

# %% [markdown]
# ## 4. Generate suitability rasters

# %% [markdown]
# ### 4.1 Functions to build suitability

# %%
def vector_to_raster(template_raster, conus_mask, gdf, value_field, output_raster):
                     
    # open the template raster and extract metadata and land mask
    with rasterio.open(template_raster) as template:

        metadata = template.meta.copy()

        # update raster data type
        metadata.update(dtype=np.int16)

        # extract land mask
        land_mask = template.read(1)
        land_mask = np.where(land_mask == 0, np.nan, 1)

        conus_file = rasterio.open(conus_mask)
        conus = conus_file.read(1)
        conus = np.where(conus == 1, 2, 0)

        # write output raster
        with rasterio.open(output_raster, 'w+', **metadata) as out:

            out_arr = out.read(1)

            # build shapes to rasterize from target geometry and field
            shapes = ((geom, value) for geom, value in zip(gdf.geometry, gdf[value_field]))

            # burn features
            burned = features.rasterize(shapes=shapes, 
                                        fill=0, 
                                        out=out_arr, 
                                        transform=out.transform)
            
            burned = np.where(burned == 1, 1, 0).astype(np.float64)
            
            # apply land mask
            # burned *= land_mask

            # # apply conus mask for offshore
            # burned += conus
            # burned = np.where(burned >= 1, 1, 0).astype(np.float64)
            
            # make nan excluded
            burned = np.where(np.isnan(burned), 1, burned)

            out.write_band(1, burned.astype(np.int16))

# %% [markdown]
# ### 4.2 Generate suitability

# %%
# read in GRIDCERF boundary shapefile
bdf = gpd.read_file(conus_shpfile)

# %% [markdown]
# #### 4.2.1 Marine Sanctuaries

# %%
# read in marine sanctuaries shapefiles, combine, and project to our GRIDCERF projection
marine_sanctuary_files = [cordell_ms_shpfile, 
                          channel_islands_ms_shpfile,
                          flower_garden_ms_shpfile,
                          florida_keys_ms_shpfile,
                          greater_farallones_ms_shpfile,
                          grays_reef_ms_shpfile,
                          monterey_bay_ms_shpfile,
                          monitor_ms_shpfile,
                          mallows_bay_ms_shpfile,
                          olympic_coast_ms_shpfile,
                          stellwagen_bank_ms_shpfile,
                          thunder_bay_ms_shpfile]

ms_gdf = gpd.GeoDataFrame()
for file in marine_sanctuary_files:
    gdf = gpd.read_file(file).to_crs(crs)
    ms_gdf = gpd.GeoDataFrame(pd.concat([ms_gdf, gdf], ignore_index=True))

# only keep marine sanctuaries within our GRIDCERF boundary
ms_gdf = gpd.clip(ms_gdf, bdf)

# add field to use for rasterization
ms_gdf["value"] = 1

ms_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster for marine sanctuaries
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=ms_gdf, 
                 value_field="value",
                 output_raster=output_marine_sanctuaries_file)

# %% [markdown]
# _____________________

# %% [markdown]
# #### 4.2.2 Offshore Danger Zones and Restricted Areas

# %%
# read in shapefile  and project to our GRIDCERF projection
danger_zone_gdf = gpd.read_file(offshore_dz_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
danger_zone_gdf = gpd.clip(danger_zone_gdf, bdf)

# add field to use for rasterization
danger_zone_gdf["value"] = 1

danger_zone_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster for marine sanctuaries
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=danger_zone_gdf, 
                 value_field="value",
                 output_raster=output_danger_zone_file)

# %% [markdown]
# #### 4.2.3 Offshore Munitions and explosives of concern

# %%
# read in shapefile and project to our GRIDCERF projection
munitions_gdf = gpd.read_file(offshore_munitions_shpfile).to_crs(crs)

# only keep areas within our GRIDCERF boundary
munitions_gdf = gpd.clip(munitions_gdf, bdf)

# add field to use for rasterization
munitions_gdf["value"] = 1

munitions_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=munitions_gdf, 
                 value_field="value",
                 output_raster=output_munitions_file)

# %% [markdown]
# #### 4.2.3 Offshore Wrecks and Obstructions

# %%
# read in shapefile  and project to our GRIDCERF projection
wrecks_gdf = gpd.read_file(offshore_wrecks_shpfile).to_crs(crs)

# only keep areas within our GRIDCERF boundary
wrecks_gdf = gpd.clip(wrecks_gdf, bdf)

# add field to use for rasterization
wrecks_gdf["value"] = 1

wrecks_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=wrecks_gdf, 
                 value_field="value",
                 output_raster=output_wrecks_file)

# %% [markdown]
# #### 4.2.5 Outer Continental Shelf Areas Withdrawn from Leasing

# %%
# read in shapefile  and project to our GRIDCERF projection
lease_gdf = gpd.read_file(withdrawn_leasing_shpfile).to_crs(crs)

#only keep areas within our GRIDCERF boundary
lease_gdf = gpd.clip(lease_gdf, bdf)

# reduce to renewable leases
lease_keep_list = ['ORSM', 'ORM']
lease_gdf = lease_gdf[lease_gdf.Lease_type.isin(lease_keep_list)]

# reduce to permanent exclusions
lease_gdf = lease_gdf[lease_gdf.Withdraw_T == 'Presidential Withdrawal - permanent']

#add field to use for rasterization
lease_gdf["value"] = 1

lease_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=lease_gdf, 
                 value_field="value",
                 output_raster=output_lease_file)

# %% [markdown]
# #### 4.2.6 Habitat Areas of Particular Concern

# %%
# read in shapefile  and project to our GRIDCERF projection
hapc_gdf = gpd.read_file(offshore_hapc_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
hapc_gdf = gpd.clip(hapc_gdf, bdf)

# add field to use for rasterization
hapc_gdf["value"] = 1

hapc_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=hapc_gdf, 
                 value_field="value",
                 output_raster=output_hapc_file)

# %% [markdown]
# #### 4.2.7 Shipping Fairways, Lanes, and Zones for US waters

# %%
# read in shapefile  and project to our GRIDCERF projection
shipping_gdf = gpd.read_file(shipping_land_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
shipping_gdf = gpd.clip(shipping_gdf, bdf)

theme_keep_list = ['Traffic Separation Schemes/Traffic Lanes',
                   'Shipping Fairways Lanes and Zones', 
                   'Traffic Separation Schemes', 
                   'Recommended Routes']

shipping_gdf = shipping_gdf[shipping_gdf.THEMELAYER.isin(theme_keep_list)]
    
shipping_gdf['geometry'] = shipping_gdf.geometry.buffer(3000)

# add field to use for rasterization
shipping_gdf["value"] = 1

shipping_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=shipping_gdf, 
                 value_field="value",
                 output_raster=output_shipping_file)

# %% [markdown]
# #### 4.2.8 State Waters

# %% [markdown]
# #### 4.2.8 State Waters

# %%
# read in shapefile  and project to our GRIDCERF projection
state_water_gdf = gpd.read_file(state_waters_shpfile).to_crs(crs)

# only keep areas within our GRIDCERF boundary
state_water_gdf = gpd.clip(state_water_gdf, bdf)

# remove non-ocean coastlines
state_water_gdf = state_water_gdf[~state_water_gdf.NAME.isin(['Great Lakes'])]

# add a 3 mile buffer to coastline
buffer_3_mi = mi_to_meter * 3
state_water_gdf["geometry"] = state_water_gdf["geometry"].buffer(buffer_3_mi)

# add field to use for rasterization
state_water_gdf["value"] = 1

state_water_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=state_water_gdf, 
                 value_field="value",
                 output_raster=output_state_waters_file)

# %% [markdown]
# #### 4.2.9 Offshore Submarine Cable Areas

# %%
# read in shapefile  and project to our GRIDCERF projection
cable_gdf = gpd.read_file(submarine_cable_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
cable_gdf = gpd.clip(cable_gdf, bdf)

# add arbitrary buffer to convert to polygon
cable_gdf['geometry'] = cable_gdf['geometry'].buffer(1000)

# add field to use for rasterization
cable_gdf["value"] = 1

cable_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster for marine sanctuaries
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=cable_gdf, 
                 value_field="value",
                 output_raster=output_cable_file)

# %%
# read in shapefile  and project to our GRIDCERF projection
cable_gdf = gpd.read_file(submarine_cable_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
cable_gdf = gpd.clip(cable_gdf, bdf)

# add arbitrary buffer to convert to polygon
cable_gdf['geometry'] = cable_gdf['geometry'].buffer(1000)

# add field to use for rasterization
cable_gdf["value"] = 1

cable_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster for marine sanctuaries
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=cable_gdf, 
                 value_field="value",
                 output_raster=output_cable_file)

# %% [markdown]
# #### 4.2.10 CONUS Land Areas

# %%
# read in shapefile  and project to our GRIDCERF projection
conus_gdf = gpd.read_file(conus_land_shpfile).to_crs(crs)

# only keep marine sanctuaries within our GRIDCERF boundary
conus_gdf = gpd.clip(conus_gdf, bdf)

# add field to use for rasterization
conus_gdf["value"] = 1

conus_gdf.plot()
# Out:
# <Axes: >

# %%
# generate raster for marine sanctuaries
vector_to_raster(template_raster=template_raster, 
                 conus_mask=conus_mask,
                 gdf=conus_gdf, 
                 value_field="value",
                 output_raster=output_conus_land_file)
